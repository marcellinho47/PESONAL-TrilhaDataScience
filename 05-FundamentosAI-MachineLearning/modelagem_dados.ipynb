# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("depara-v2.csv")
df
# Out:
#       De_CodFolha                    De_DescFolha  De_CodEvento  \
# 0               1                          MENSAL            10
# 1               1                          MENSAL           210
# 2               1                          MENSAL           350
# 3               1                          MENSAL          1680
# 4               1                          MENSAL         22730
# ...           ...                             ...           ...
# 2398           16  RESCISÃO COMP. DIF. SALARIAL           10890
# 2399           16  RESCISÃO COMP. DIF. SALARIAL           11910
# 2400           16  RESCISÃO COMP. DIF. SALARIAL           22920
# 2401           16  RESCISÃO COMP. DIF. SALARIAL           22930
# 2402           16  RESCISÃO COMP. DIF. SALARIAL           23175
#
#                              De_DescEvento De_TipoEvento  \
# 0                           SALARIO MENSAL             P
# 1                       DIFERENCA SALARIAL             P
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2403 entries, 0 to 2402
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   De_CodFolha           2403 non-null   int64
#  1   De_DescFolha          2403 non-null   object
#  2   De_CodEvento          2403 non-null   int64
#  3   De_DescEvento         2403 non-null   object
#  4   De_TipoEvento         2403 non-null   object
#  5   DataUltimaUtilizacao  2403 non-null   int64
#  6   Para_CodFolha         2022 non-null   float64
#  7   Para_DescFolha        2040 non-null   object
#  8   Para_CodEvento        2160 non-null   float64
#  9   Para_DescEvento       2403 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 187.9+ KB

# %%
df.describe()
# Out:
#        De_CodFolha  De_CodEvento  DataUltimaUtilizacao  Para_CodFolha  \
# count  2403.000000   2403.000000           2403.000000    2022.000000
# mean      5.287973  14776.350395         201950.706201       5.801682
# std       4.364565   7724.193191            570.224644       8.624771
# min       1.000000     10.000000         199702.000000       1.000000
# 25%       1.000000  10225.000000         201806.000000       1.000000
# 50%       5.000000  12160.000000         202306.000000       4.000000
# 75%       7.000000  22845.000000         202310.000000       5.000000
# max      16.000000  24980.000000         202310.000000      40.000000
#
#        Para_CodEvento
# count     2160.000000
# mean     17526.462500
# std       9559.569416
# min          5.000000
# 25%       9820.000000
# 50%      20210.000000
# 75%      27179.000000
# max      28485.000000

# %%
df.hist(bins=50, figsize=(30, 15))
# Out:
# array([[<Axes: title={'center': 'De_CodFolha'}>,
#         <Axes: title={'center': 'De_CodEvento'}>],
#        [<Axes: title={'center': 'DataUltimaUtilizacao'}>,
#         <Axes: title={'center': 'Para_CodFolha'}>],
#        [<Axes: title={'center': 'Para_CodEvento'}>, <Axes: >]],
#       dtype=object)

# %%
df["De_CodFolha"].value_counts()
# Out:
# De_CodFolha
# 1     708
# 5     557
# 7     205
# 2     179
# 8     147
# 12    132
# 3     111
# 16     72
# 4      70
# 14     64
# 13     61
# 15     47
# 11     26
# 10     18
# 6       6
# Name: count, dtype: int64

# %%
df["Para_CodFolha"].value_counts()
# Out:
# Para_CodFolha
# 1.0     691
# 5.0     551
# 8.0     204
# 2.0     176
# 4.0     109
# 3.0      70
# 39.0     64
# 13.0     61
# 40.0     47
# 10.0     26
# 11.0     14
# 6.0       6
# 12.0      3
# Name: count, dtype: int64

# %% [markdown]
# Limpeza de dados

# %%
df_cleaned = df.drop(["De_TipoEvento", "DataUltimaUtilizacao"], axis=1)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2403 entries, 0 to 2402
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   De_CodFolha      2403 non-null   int64
#  1   De_DescFolha     2403 non-null   object
#  2   De_CodEvento     2403 non-null   int64
#  3   De_DescEvento    2403 non-null   object
#  4   Para_CodFolha    2022 non-null   float64
#  5   Para_DescFolha   2040 non-null   object
#  6   Para_CodEvento   2160 non-null   float64
#  7   Para_DescEvento  2403 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 150.3+ KB

# %%
df_cleaned.head()
# Out:
#    De_CodFolha De_DescFolha  De_CodEvento  \
# 0            1       MENSAL            10
# 1            1       MENSAL           210
# 2            1       MENSAL           350
# 3            1       MENSAL          1680
# 4            1       MENSAL         22730
#
#                           De_DescEvento  Para_CodFolha Para_DescFolha  \
# 0                        SALARIO MENSAL            1.0         MENSAL
# 1                    DIFERENCA SALARIAL            1.0         MENSAL
# 2       DIF.SALARIAL REF. CONV.COLETIVA            1.0         MENSAL
# 3  DIF.SALARIAL DISSICIO COLETIVO 06/07            1.0         MENSAL
# 4            DIF.REMUN.S/ CONV.COLETIVA            1.0         MENSAL
#
#    Para_CodEvento     Para_DescEvento
# 0             5.0             SALARIO
# 1             6.0  DIF SALARIO MENSAL
# 2             6.0  DIF SALARIO MENSAL
# 3             6.0  DIF SALARIO MENSAL
# 4             6.0  DIF SALARIO MENSAL

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

district_encoded = ordinal_encoder.fit_transform(df_cleaned[["De_DescEvento"]])
district_encoded
# Out:
# array([[916.],
#        [395.],
#        [392.],
#        ...,
#        [660.],
#        [661.],
#        [629.]])

# %%
## 5. Selecione e treino múltiplos modelos
